# %% [markdown]
# <a href="https://colab.research.google.com/github/shubham-dahifale123/machine_learning/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EDA univarite analysis is performed only on one column of particular table**

# %%
import pandas as pd
import seaborn as sns
tips=sns.load_dataset("tips")
flights=sns.load_dataset("flights")
iris=sns.load_dataset("iris")
#df=tips.copy()

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(tips['smoker'])
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.countplot(tips['sex'],color='orange')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
tips['smoker'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# univriate analysis on numerical data

# %%
import matplotlib.pyplot as plt
plt.hist(tips['tip'])
# Out:
# (array([41., 79., 66., 27., 19.,  5.,  4.,  1.,  1.,  1.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(tips['total_bill'])
# Out:
# /tmp/ipykernel_3679/4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(tips['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# **bivariate work on two coulumn of table and multivariate works on multiple column of table**

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='smoker', y='total_bill', data=tips)
plt.title('Average Total Bill by Smoker Status')
plt.xlabel('Smoker')
plt.ylabel('Average Total Bill')
plt.show()
